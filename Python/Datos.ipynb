# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import random

# %%
data = pd.read_csv('completo+respuesta+headers.csv', header=0, index_col=False)

# %%
data.describe()
# Out:
#              X-axis        Y-axis        Z-axis         Label
# count  19337.000000  19337.000000  19337.000000  19337.000000
# mean      -3.036879     -3.869599      4.779501      1.413456
# std        7.213168      8.843972      6.318493      1.108777
# min      -78.437500    -78.437500    -57.375000      0.000000
# 25%       -7.925781     -4.355469      0.378174      0.000000
# 50%       -0.445312     -1.120117      3.107422      1.000000
# 75%       -0.067017     -0.351807     10.351562      2.000000
# max       72.937500     78.437500     78.437500      3.000000

# %%
reposo = data[data.Label == 0]
reposo = reposo.drop(['Label'], axis=1)

# %%
reposo.describe()
# Out:
#             X-axis       Y-axis       Z-axis
# count  5356.000000  5356.000000  5356.000000
# mean     -0.091385    -0.363739    10.359101
# std       0.037410     0.026726     0.023491
# min      -0.926270    -0.619629    10.007812
# 25%      -0.105286    -0.378174    10.351562
# 50%      -0.088562    -0.363770    10.359375
# 75%      -0.074219    -0.349365    10.367188
# max       0.605469     0.385254    11.187500

# %%
andando = data[data.Label == 1]
andando = andando.drop(['Label'], axis=1)

# %%
corriendo = data[data.Label == 2]
corriendo = corriendo.drop(['Label'], axis=1)

# %%
cayendo = data[data.Label == 3]
cayendo = cayendo.drop(['Label'], axis=1)

# %%
andando.describe()
# Out:
#             X-axis       Y-axis       Z-axis
# count  4815.000000  4815.000000  4815.000000
# mean     -9.978337    -2.977451     0.679224
# std       3.550272     1.980726     1.415865
# min     -25.953125   -16.734375    -6.371094
# 25%     -12.320312    -4.183594    -0.153198
# 50%      -9.578125    -2.759766     0.552734
# 75%      -7.468750    -1.654297     1.306641
# max      11.601562     8.281250    14.507812

# %%
corriendo.describe()
# Out:
#             X-axis       Y-axis       Z-axis
# count  4981.000000  4981.000000  4981.000000
# mean     -0.632807   -11.085089     1.323010
# std       7.645861    12.869971     3.306390
# min     -34.000000   -64.437500   -19.078125
# 25%      -7.351562   -21.015625    -0.383057
# 50%      -1.217773    -7.718750     0.950195
# 75%       6.132812    -0.334961     2.667969
# max      36.156250    14.281250    23.859375

# %%
cayendo.describe()
# Out:
#             X-axis       Y-axis       Z-axis
# count  4185.000000  4185.000000  4185.000000
# mean     -1.681473    -0.794982     6.470128
# std       9.005075     8.468682     9.638507
# min     -78.437500   -78.437500   -57.375000
# 25%      -2.519531    -3.671875     2.908203
# 50%      -0.703613    -1.117188     8.531250
# 75%       0.892578     2.251953    10.039062
# max      72.937500    78.437500    78.437500

# %%
ax = reposo.plot(kind='line', title='Datos reposo')
ax.set(xlabel='Muestras', ylabel='Aceleración (m/s^2)')
plt.show()

# %%
ax = andando.plot(kind='line', title='Datos andando')
ax.set(xlabel='Muestras', ylabel='Aceleración (m/s^2)')
plt.show()

# %%
ax = corriendo.plot(kind='line', title='Datos corriendo')
ax.set(xlabel='Muestras', ylabel='Aceleración (m/s^2)')
plt.show()

# %%
ax = cayendo.plot(kind='line', title='Datos cayendo')
ax.set(xlabel='Muestras', ylabel='Aceleración (m/s^2)')
plt.show()
